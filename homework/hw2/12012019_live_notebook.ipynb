# %% [markdown]
# # Office Hours 12/1/2019 Supplemental Notebook

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../../mcis6273_f19_datamining/github/mcis6273_f19_datamining/homework/hw1/openpowerlifting-2019-10-24.csv")

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Wilks', 'McCulloch',
#        'Glossbrenner', 'IPFPoints', 'Tested', 'Country', 'Federation', 'Date',
#        'MeetCountry', 'MeetState', 'MeetName'],
#       dtype='object')

# %%
df.query('Age > 30 & Age < 40').describe()
# Out:
#                 Age  BodyweightKg      Squat1Kg      Squat2Kg      Squat3Kg  \
# count  37302.000000  36718.000000  14758.000000  14574.000000  13983.000000
# mean      34.552638     88.930078    125.460192     96.403352     26.197292
# std        2.679050     23.188852    162.286502    193.299931    219.740830
# min       30.500000     40.600000   -455.000000   -467.500000   -477.500000
# 25%       32.000000     72.700000     95.000000     65.000000   -192.500000
# 50%       34.500000     88.200000    167.500000    160.000000    112.500000
# 75%       37.000000    103.700000    225.000000    227.500000    210.000000
# max       39.500000    242.400000    492.150000    512.560000    526.170000
#
#          Squat4Kg  Best3SquatKg      Bench1Kg      Bench2Kg      Bench3Kg  \
# count  102.000000  20564.000000  24472.000000  24179.000000  23277.000000
# mean    77.242157    208.320791     93.440259     56.596837    -23.543049
# ...

# %%
list(df.Country.value_counts().index)
# Out:
# ['USA',
#  'Russia',
#  'Australia',
#  'Ukraine',
#  'Germany',
#  'UK',
#  'Japan',
#  'Canada',
#  'England',
#  'South Africa',
#  'New Zealand',
#  'Mexico',
#  'Austria',
#  'France',
#  'Netherlands',
#  'Finland',
#  'Puerto Rico',
#  'Ireland',
#  'Sweden',
#  'Poland',
#  'Belgium',
#  'Slovakia',
#  'Spain',
#  'Norway',
#  'Chile',
#  'Argentina',
#  'Brazil',
#  'Italy',
#  'Kazakhstan',
#  'India',
#  'Ecuador',
#  'Czechia',
#  'Belarus',
#  'Scotland',
#  'Algeria',
#  'Wales',
#  'Hungary',
#  'Colombia',
#  'Slovenia',
#  'Taiwan',
#  'Peru',
#  'Croatia',
#  'Nauru',
#  'Iceland',
#  'Bahamas',
#  'Papua New Guinea',
#  'Georgia',
#  'USSR',
#  'Iran',
#  'Latvia',
#  'Denmark',
#  'Portugal',
#  'Egypt',
#  'Cook Islands',
#  'Guatemala',
#  'Libya',
#  'Switzerland',
#  'Azerbaijan',
#  'N.Ireland',
#  'Venezuela',
#  'Lebanon',
#  'Honduras',
#  'China',
#  'Morocco',
#  'Israel',
#  'Sri Lanka',
#  'Bulgaria',
#  'Serbia',
#  'Costa Rica',
#  'Nigeria',
# ...

# %%
df.Country.value_counts()[:20].plot.bar()

# %%
df.query('Best3SquatKg<0')
# Out:
#                        Name Sex Event   Equipment   Age AgeClass  \
# 1445          Stefan Tarzia   M   SBD       Wraps  24.0    24-34
# 5789            Sam Pennell   M   SBD       Wraps  27.0    24-34
# 6073        Declan Bradbury   M   SBD       Wraps  21.0    20-23
# 6102           Scott Walker   M   SBD       Wraps  25.0    24-34
# 7210               Ian Neil   M   SBD       Wraps  64.0    60-64
# ...                     ...  ..   ...         ...   ...      ...
# 330267  Aleksandra Kajganić   F   SBD         Raw   NaN      NaN
# 330274           Nina Kovaĉ   F   SBD         Raw   NaN      NaN
# 341112         Toby Swallow   M   SBD  Single-ply   NaN      NaN
# 345539             H. Clark   M   SBD         Raw   NaN      NaN
# 353407         Tania Robins   F   SBD         Raw   NaN      NaN
#
#        BirthYearClass  Division  BodyweightKg WeightClassKg  ...  McCulloch  \
# 1445            24-39      M-OR          81.0          82.5  ...        NaN
# ...

# %%
df.Best3SquatKg.dtype
# Out:
# dtype('float64')

# %%
df.Date.dtype
# Out:
# dtype('O')

# %%
df.Date[:10]
# Out:
# 0    2018-10-27
# 1    2018-10-27
# 2    2018-10-27
# 3    2018-10-27
# 4    2018-10-27
# 5    2018-10-27
# 6    2018-10-27
# 7    2018-10-27
# 8    2018-10-27
# 9    2018-10-27
# Name: Date, dtype: object

# %%
df.Date.str[:4].value_counts(sort=False).sort_index()
# Out:
# 1964       21
# 1965       45
# 1966       50
# 1967       44
# 1968       63
# 1969       41
# 1970       44
# 1971       88
# 1972      103
# 1973       54
# 1974       58
# 1975       76
# 1976      117
# 1977       75
# 1978       69
# 1979     2516
# 1980    19315
# 1981    20854
# 1982    17020
# 1983     3999
# 1984     3570
# 1985     4120
# 1986     3926
# 1987     4322
# 1988     5253
# 1989     6631
# 1990     6981
# 1991     6178
# 1992     8024
# 1993     7454
# 1994     5643
# 1995     6434
# 1996     5655
# 1997     5981
# 1998     7987
# 1999     5536
# 2000     4725
# 2001     4512
# 2002     5526
# 2003     6369
# 2004     4698
# 2005     3158
# 2006     3998
# 2007     3699
# 2008     4391
# 2009     6618
# 2010    19725
# 2011    20815
# 2012    20785
# 2013    23250
# 2014    22663
# 2015    31350
# 2016    35291
# 2017    38663
# 2018    39196
# 2019    31730
# Name: Date, dtype: int64

# %%
df.Date.str[:4].value_counts(sort=False).sort_index().plot.bar()

# %%
df.Bench4Kg.describe()
# Out:
# count    2197.000000
# mean       42.562353
# std       165.784775
# min      -460.000000
# 25%      -110.000000
# 50%       102.060000
# 75%       167.500000
# max       425.000000
# Name: Bench4Kg, dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Wilks', 'McCulloch',
#        'Glossbrenner', 'IPFPoints', 'Tested', 'Country', 'Federation', 'Date',
#        'MeetCountry', 'MeetState', 'MeetName'],
#       dtype='object')

# %%
df.Glossbrenner
# Out:
# 0         286.42
# 1         334.16
# 2          34.12
# 3         305.37
# 4         274.56
#            ...
# 489505    228.14
# 489506    169.92
# 489507    366.65
# 489508    373.33
# 489509       NaN
# Name: Glossbrenner, Length: 489510, dtype: float64

# %%
df.Name.value_counts()
# Out:
# Max Bristow        128
# R. Smith           115
# Martin Drake       113
# Smith               97
# John Myers          97
#                   ...
# Jarman               1
# D. Van Holt          1
# Dmitro Bondarev      1
# Debbie Magliaro      1
# Preston Bluett       1
# Name: Name, Length: 192300, dtype: int64

# %%
df.query('Name == "Max Bristow"').loc[:,'TotalKg'].describe()
# Out:
# count    128.000000
# mean     421.617188
# std      160.065999
# min       52.500000
# 25%      356.875000
# 50%      510.000000
# 75%      520.000000
# max      540.000000
# Name: TotalKg, dtype: float64

# %%
df.Tested.value_counts()
# Out:
# Yes    322258
# Name: Tested, dtype: int64

# %%
df.AgeClass.unique()
# Out:
# array(['24-34', '40-44', '20-23', '45-49', '35-39', '18-19', '50-54',
#        '16-17', '80-999', '70-74', nan, '65-69', '13-15', '60-64',
#        '55-59', '75-79', '5-12'], dtype=object)

# %%
features = [
     'Sex', 
     'Age',
     'BodyweightKg',
     'Best3SquatKg',
     'Best3BenchKg',
     'Best3DeadliftKg', 
     'TotalKg', 
     'Date'   
]

# %%
df.loc[:,features]
# Out:
#        Sex   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  \
# 0        F  29.0         59.80        105.00         55.00           130.00
# 1        F  29.0         58.50        120.00         67.50           145.00
# 2        F  40.0         55.40           NaN         32.50              NaN
# 3        F  23.0         60.00        105.00         72.50           132.50
# 4        F  45.0        104.00        140.00         80.00           170.00
# ...     ..   ...           ...           ...           ...              ...
# 489505   M   NaN         71.58        111.13         65.77           142.88
# 489506   M   NaN         72.44         83.91         54.43           102.06
# 489507   M   NaN         80.60        213.19        115.67           231.33
# 489508   M   NaN         75.39        195.04        122.47           226.80
# 489509   M   NaN         82.05        165.56        108.86           174.63
#
#         TotalKg        Date
# ...

# %%
df.loc[:,'Year'] = df.Date.str[:4]

# %%
df.dropna(subset=['Year'])
# Out:
#                    Name Sex Event   Equipment   Age AgeClass BirthYearClass  \
# 0          Abbie Murphy   F   SBD       Wraps  29.0    24-34            NaN
# 1           Abbie Tuong   F   SBD       Wraps  29.0    24-34            NaN
# 2        Ainslee Hooper   F     B         Raw  40.0    40-44          40-49
# 3       Amy Moldenhauer   F   SBD       Wraps  23.0    20-23            NaN
# 4          Andrea Rowan   F   SBD       Wraps  45.0    45-49          40-49
# ...                 ...  ..   ...         ...   ...      ...            ...
# 489504      Jack Delmar   M   SBD  Single-ply   NaN      NaN            NaN
# 489505    Andrew Kubena   M   SBD  Single-ply   NaN      NaN            NaN
# 489506  Barrett Janecek   M   SBD  Single-ply   NaN      NaN            NaN
# 489507      Greg Sexton   M   SBD  Single-ply   NaN      NaN            NaN
# 489508        Rj Denson   M   SBD  Single-ply   NaN      NaN            NaN
#
# ...
